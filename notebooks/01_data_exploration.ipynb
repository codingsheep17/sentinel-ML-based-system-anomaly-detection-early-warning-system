# %% [markdown]
# Exploring the data and cleaning

# %%
import pandas as pd

df = pd.read_csv("D:/Desktop/sentinelml/data/raw/ec2_cpu_utilization.csv")

# %%
df.head(5)
# Out:
#              timestamp  value
# 0  2014-02-14 14:30:00  0.132
# 1  2014-02-14 14:35:00  0.134
# 2  2014-02-14 14:40:00  0.134
# 3  2014-02-14 14:45:00  0.134
# 4  2014-02-14 14:50:00  0.134

# %%
df.isnull().sum()
# Out:
# timestamp    0
# value        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.rename(columns={"value":"cpu_utilization"})

# %%
df.columns
# Out:
# Index(['timestamp', 'cpu_utilization'], dtype='str')

# %%
#changing the datatime format
df["timestamp"] = pd.to_datetime(df['timestamp'])

# %%
#arranging the order
df = df.sort_values(by="timestamp")

# %%
df.dtypes
# Out:
# timestamp          datetime64[us]
# cpu_utilization           float64
# dtype: object

# %%
#saving the cleaned set back to the processed folder
df.to_csv("D:/Desktop/sentinelml/data/processed/processed.csv", index=False)
